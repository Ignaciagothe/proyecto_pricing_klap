# %%
import pandas as pd

comercio_mes = pd.read_csv("agregacion_comercio_mes.csv")
comercio_mes
# Out:
#         periodo rut_comercio  qtrx_total   monto_clp  n_local  n_terminal  \
# 0       2024-01   10000001-6      2296.0  10207680.0        1           1
# 1       2024-01   10000539-5         8.0    640000.0        1           1
# 2       2024-01   10001448-3       602.0   2849392.0        1           1
# 3       2024-01   10002450-0        56.0   2624420.0        1           1
# 4       2024-01   10004726-8        10.0     33322.0        2           2
# ...         ...          ...         ...         ...      ...         ...
# 152035  2024-12    9964268-8      4392.0  18515320.0        1           1
# 152036  2024-12    9971562-6      1572.0   7970200.0        1           1
# 152037  2024-12    9983607-5         2.0     32180.0        1           1
# 152038  2024-12    9994855-8      3584.0  34920820.0        1           3
# 152039  2024-12    9999543-2      1140.0   6089670.0        1           2
#
#         n_tecnologias  fecha_baja  monto_visa  monto_mastercard  monto_amex  \
# ...

# %%
display(comercio_mes.describe())
# Out:
#          qtrx_total     monto_clp        n_local     n_terminal  \
# count  1.520400e+05  1.520400e+05  152040.000000  152040.000000
# mean   1.170578e+04  1.128659e+08       1.569541       2.762937
# std    5.858956e+05  4.459777e+09       7.374536      16.866648
# min    1.000000e+00  1.000000e+02       1.000000       1.000000
# 25%    8.600000e+01  8.275435e+05       1.000000       1.000000
# 50%    4.880000e+02  3.746610e+06       1.000000       1.000000
# 75%    1.618000e+03  1.125098e+07       1.000000       2.000000
# max    7.127211e+07  5.065815e+11     456.000000    1154.000000
#
#        n_tecnologias    fecha_baja    monto_visa  monto_mastercard  \
# count  152040.000000  2.866300e+04  1.520400e+05      1.520400e+05
# mean        1.388108  2.024050e+07  4.214732e+07      1.425329e+07
# std         0.747657  2.631212e+02  1.652805e+09      5.849362e+08
# min         1.000000  2.024010e+07  0.000000e+00      0.000000e+00
# ...

# %%
descripcion = comercio_mes.describe()
descripcion.to_excel("descripcion_comercio_mes.xlsx")

# %%
comercio_mes
# Out:
#         periodo rut_comercio  qtrx_total   monto_clp  n_local  n_terminal  \
# 0       2024-01   10000001-6      2296.0  10207680.0        1           1
# 1       2024-01   10000539-5         8.0    640000.0        1           1
# 2       2024-01   10001448-3       602.0   2849392.0        1           1
# 3       2024-01   10002450-0        56.0   2624420.0        1           1
# 4       2024-01   10004726-8        10.0     33322.0        2           2
# ...         ...          ...         ...         ...      ...         ...
# 152035  2024-12    9964268-8      4392.0  18515320.0        1           1
# 152036  2024-12    9971562-6      1572.0   7970200.0        1           1
# 152037  2024-12    9983607-5         2.0     32180.0        1           1
# 152038  2024-12    9994855-8      3584.0  34920820.0        1           3
# 152039  2024-12    9999543-2      1140.0   6089670.0        1           2
#
#         n_tecnologias  fecha_baja  monto_visa  monto_mastercard  monto_amex  \
# ...

# %%
rut_exluir=pd.read_excel("rut_excluir.xlsx")
